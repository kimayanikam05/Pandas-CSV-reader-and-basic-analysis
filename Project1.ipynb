# %%
import pandas as pd

#1.
df = pd.read_csv("dataa.csv")
print(df.head())
print(df.tail())

#2.
print("Mean:\n", df.mean(numeric_only=True))
print("Median:\n", df.median(numeric_only=True))
print("Min:\n", df.min(numeric_only=True))
print("Max:\n", df.max(numeric_only=True))
print("Count:\n", df.count())

#3.
filtered.to_csv("filtered_data.csv", index=False)

#4.
filtered.to_excel("filtered_data.xlsx", index=False)
print("Files saved successfully!")
# Out:
#     Name  Age  Marks        City
# 0   Amit   20     85      Mumbai
# 1   Neha   21     90        Pune
# 2  Rahul   19     72      Nashik
# 3  Sneha   22     95      Nagpur
# 4  Kiran   20     60  Aurangabad
#     Name  Age  Marks        City
# 0   Amit   20     85      Mumbai
# 1   Neha   21     90        Pune
# 2  Rahul   19     72      Nashik
# 3  Sneha   22     95      Nagpur
# 4  Kiran   20     60  Aurangabad
# Mean:
#  Age      20.4
# Marks    80.4
# dtype: float64
# Median:
#  Age      20.0
# Marks    85.0
# dtype: float64
# Min:
#  Age      19
# Marks    60
# dtype: int64
# Max:
#  Age      22
# Marks    95
# dtype: int64
# Count:
#  Name     5
# Age      5
# Marks    5
# City     5
# dtype: int64
# Files saved successfully!
